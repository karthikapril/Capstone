# %%
from pymongo import MongoClient
import csv
import pandas as pd
import numpy as np

# %%
mongo_client = MongoClient("mongodb+srv://karthikeyanapril5:1578@cluster0.kngfgwp.mongodb.net/?retryWrites=true&w=majority")

# %%
db = mongo_client['sample_airbnb']

# %%
collection = db['listingsAndReviews']

# %%
document_count = collection.count_documents({})

# %%
cursor = collection.find({})

# %%
data_list = list(cursor)

# %%
df = pd.DataFrame(data_list)

# %%
df
# Out:
#            _id                            listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name  \
# 0                               Ribeira Charming Duplex
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                              Private Room in Bushwick
# ...

# %%
df['review_score'] = df['review_scores'].apply(lambda x: x.get('review_scores_accuracy') if isinstance(x, dict) else None)

# %%
df['hostid'] = df['host'].apply(lambda x: x.get('host_id') if isinstance(x, dict) else None)

# %%
df['hostname'] = df['host'].apply(lambda x: x.get('host_name') if isinstance(x, dict) else None)

# %%
df['Country'] = df['address'].apply(lambda x: x.get('country') if isinstance(x, dict) else None)

# %%
df['Rating'] = df['review_scores'].apply(lambda x: x.get('review_scores_rating') if isinstance(x, dict) else None)

# %%
x = ['name', 'summary', 'price','space','cleaning_fee','description', 'hostid', 'hostname', 'Country', 'Rating', 'room_type', 'bed_type', 'accommodates','bedrooms', 'property_type', 'beds']

# %%
Airbnb_df = df[x]

# %%
Airbnb_df.head()
# Out:
#                                name  \
# 0           Ribeira Charming Duplex
# 1      Horto flat with small garden
# 2  Ocean View Waikiki Marina w/prkg
# 3          Private Room in Bushwick
# 4       Apt Linda Vista Lagoa - Rio
#
#                                              summary   price  \
# 0  Fantastic duplex apartment with three bedrooms...   80.00
# 1  One bedroom + sofa-bed in quiet and bucolic ne...  317.00
# 2  A short distance from Honolulu's billion dolla...  115.00
# 3  Here exists a very cozy room for rent in a sha...   40.00
# 4  Quarto com vista para a Lagoa Rodrigo de Freit...  701.00
#
#                                                space cleaning_fee  \
# 0  Privileged views of the Douro River and Ribeir...        35.00
# 1  Lovely one bedroom + sofa-bed in the living ro...       187.00
# 2  Great studio located on Ala Moana across the s...       100.00
# 3                                                             NaN
# ...

# %%
Airbnb_df.drop('space', axis = 1, inplace = True)
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_11664\178738302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Airbnb_df.drop('space', axis = 1, inplace = True)

# %%
Airbnb_df.isnull().sum()
# Out:
# name                0
# summary             0
# price               0
# cleaning_fee     1531
# description         0
# hostid              0
# hostname            0
# Country             0
# Rating           1474
# room_type           0
# bed_type            0
# accommodates        0
# bedrooms            5
# property_type       0
# beds               13
# dtype: int64

# %%
Airbnb_df.to_csv('Airbnb_data3.csv', index=False)

# %%
Airbnbcsv = pd.read_csv(r"C:\Users\VICTUS\Desktop\Airbnb 3\Airbnb_data3.csv")

# %%
Airbnbcsv.head()
# Out:
#                                name  \
# 0           Ribeira Charming Duplex
# 1      Horto flat with small garden
# 2  Ocean View Waikiki Marina w/prkg
# 3          Private Room in Bushwick
# 4       Apt Linda Vista Lagoa - Rio
#
#                                              summary  price  cleaning_fee  \
# 0  Fantastic duplex apartment with three bedrooms...   80.0          35.0
# 1  One bedroom + sofa-bed in quiet and bucolic ne...  317.0         187.0
# 2  A short distance from Honolulu's billion dolla...  115.0         100.0
# 3  Here exists a very cozy room for rent in a sha...   40.0           NaN
# 4  Quarto com vista para a Lagoa Rodrigo de Freit...  701.0         250.0
#
#                                          description    hostid     hostname  \
# 0  Fantastic duplex apartment with three bedrooms...  51399391  Ana&Gonçalo
# 1  One bedroom + sofa-bed in quiet and bucolic ne...   1282196        Ynaie
# ...

# %%
Airbnbcsv.isnull().sum()
# Out:
# name                8
# summary           258
# price               0
# cleaning_fee     1531
# description        95
# hostid              0
# hostname            0
# Country             0
# Rating           1474
# room_type           0
# bed_type            0
# accommodates        0
# bedrooms            5
# property_type       0
# beds               13
# dtype: int64

# %%
num_features = ['cleaning_fee','Rating', 'beds']
for i in num_features:
    mean = Airbnbcsv[i].mean()
    Airbnbcsv[i].fillna(mean,inplace=True)
    
cat_features = ['name','description']
for i in cat_features:
    non_null_values = Airbnbcsv[i].dropna().unique()
    Airbnbcsv[i] = Airbnbcsv[i].apply(lambda x: np.random.choice(non_null_values) if pd.isnull(x) else x)

# %%
Airbnbcsv.drop('summary', axis = 1, inplace = True)

# %%
Airbnbcsv.isnull().sum()
# Out:
# name             0
# price            0
# cleaning_fee     0
# description      0
# hostid           0
# hostname         0
# Country          0
# Rating           0
# room_type        0
# bed_type         0
# accommodates     0
# bedrooms         5
# property_type    0
# beds             0
# dtype: int64

# %%
df1 = pd.DataFrame(Airbnbcsv)

# %%
df1.head()
# Out:
#                                name  price  cleaning_fee  \
# 0           Ribeira Charming Duplex   80.0     35.000000
# 1      Horto flat with small garden  317.0    187.000000
# 2  Ocean View Waikiki Marina w/prkg  115.0    100.000000
# 3          Private Room in Bushwick   40.0     94.074801
# 4       Apt Linda Vista Lagoa - Rio  701.0    250.000000
#
#                                          description    hostid     hostname  \
# 0  Fantastic duplex apartment with three bedrooms...  51399391  Ana&Gonçalo
# 1  One bedroom + sofa-bed in quiet and bucolic ne...   1282196        Ynaie
# 2  A short distance from Honolulu's billion dolla...   5448114        David
# 3  Here exists a very cozy room for rent in a sha...  11275734         Josh
# 4  Quarto com vista para a Lagoa Rodrigo de Freit...  51496939        Livia
#
#          Country     Rating        room_type  bed_type  accommodates  \
# 0       Portugal   89.00000  Entire home/apt  Real Bed             8
# ...

# %%
df1.isnull().sum()
# Out:
# name             0
# price            0
# cleaning_fee     0
# description      0
# hostid           0
# hostname         0
# Country          0
# Rating           0
# room_type        0
# bed_type         0
# accommodates     0
# bedrooms         5
# property_type    0
# beds             0
# dtype: int64

# %%
df1.to_csv('Airbnb_clean_data3.csv')
